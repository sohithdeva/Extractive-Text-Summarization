# %%
pip install gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gensim --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:21: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(
# ...

# %%
pip list -o
# Out:
# Package                  Version             Latest     TypeNote: you may need to restart the kernel to use updated packages.
#
# ------------------------ ------------------- ---------- -----
# asn1crypto               1.3.0               1.4.0      wheel
# astropy                  4.0.1.post1         4.2        wheel
# attrs                    19.3.0              20.3.0     wheel
# autopep8                 1.5.3               1.5.5      wheel
# Babel                    2.8.0               2.9.0      wheel
# bcrypt                   3.1.7               3.2.0      wheel
# beautifulsoup4           4.9.1               4.9.3      wheel
# bitarray                 1.4.0               1.6.3      sdist
# bleach                   3.1.5               3.3.0      wheel
# bokeh                    2.1.1               2.2.3      sdist
# certifi                  2020.6.20           2020.12.5  wheel
# cffi                     1.14.0              1.14.4     wheel
# ...

# %%
pip install -U gensim
# Out:
# Requirement already up-to-date: gensim in c:\users\sohith\appdata\roaming\python\python38\site-packages (3.8.3)Note: you may need to restart the kernel to use updated packages.
#
# ...

# %%
from gensim.summarization import keywords

# %%
from gensim.summarization.summarizer import summarize

# %%
texts1 = "I am Deva Sohith from the Hyderabad campus. In the first round of allotment, I was allotted Rupeek Fintech which is my first preference. But unfortunately, it got backed out on 10th January. After that, I got a call and mail from UBS asking to share all the documents to start the onboarding process for PS2 ( I am attaching the mail for reference). But now UBS is not possible as their internship process is starting in March. So, both the finance stations allotted to me got canceled. Currently, my station allotment is in process. But the main problem is there are no finance stations available. By the time Rupeek Fintech got backed out, all the finance stations were filled. I also feel that it is very difficult to get a finance station right now. I have done two summer terms and a semester to complete all the finance courses. Though my CGPA is less"

# %%
print(texts1)
# Out:
# I am Deva Sohith from the Hyderabad campus. In the first round of allotment, I was allotted Rupeek Fintech which is my first preference. But unfortunately, it got backed out on 10th January. After that, I got a call and mail from UBS asking to share all the documents to start the onboarding process for PS2 ( I am attaching the mail for reference). But now UBS is not possible as their internship process is starting in March. So, both the finance stations allotted to me got canceled. Currently, my station allotment is in process. But the main problem is there are no finance stations available. By the time Rupeek Fintech got backed out, all the finance stations were filled. I also feel that it is very difficult to get a finance station right now. I have done two summer terms and a semester to complete all the finance courses. Though my CGPA is less

# %%
print(summarize(texts1, ratio=0.5))
# Out:
# After that, I got a call and mail from UBS asking to share all the documents to start the onboarding process for PS2 ( I am attaching the mail for reference).
# But now UBS is not possible as their internship process is starting in March.
# So, both the finance stations allotted to me got canceled.
# Currently, my station allotment is in process.
# By the time Rupeek Fintech got backed out, all the finance stations were filled.
# I also feel that it is very difficult to get a finance station right now.

# %% [markdown]
# #### Summary
# Gensim library is used here for the task of text summarization. It is the most famous deep NLP Library.
# **Functions Used : Summarize and Keywords** <br>
# This algorithm produces half of the original sentances from the given text by taking the argument ratio. It is extractive summarization as there are no new words/sentences created. The are algorithms which can be used for generative summarization(where algorithms come up with it's own words).

# %% [markdown]
# #### About Algorithm
# **Road Map: RAW Text -> Cleaned Text -> Sentences -> Tokenized sentences -> Sentence Vector -> Similarity Matrix -> Graph -> Ranking -> Summary**
# * Raw text is of no worth, we have to convert to clean text as the process of text pre-processing. We remove capital letters, puntuations, numbers.
# * The cleaned text is divided into sentences.
# * Sentences are divided into words (Toknization of sentences)
# * Sentence vectors are formed by using word vectors (Made into numbers) - Appending the word vectors. We can also use **TF-IDF** to do (Word vectors perform well).
# * A similarity matrix nXn is formed, where n is the number of sentence vectors.
# * A graph is formed, **where nodes are sentences and Edges represent similarity** (Every node is connected to other node as the similarity between two sentences always exists). Hence it is a complete graph.
# * For ranking we use **Page Ranking Algorithm** (which google uses). In Page ranking algorithm, the pages are treated as nodes and similarity is treated as edges. The **score** denotes the probability of user accessing the link. In our case, the **score** represents importance of particular sentence in the text.
# * All the sentences are ranked in the order of score and top K lines are displayed.

# %% [markdown]
# ![text%20summ.PNG](attachment:text%20summ.PNG)

# %%
print(summarize(texts1, split= True, ratio=0.5))
# Out:
# ['After that, I got a call and mail from UBS asking to share all the documents to start the onboarding process for PS2 ( I am attaching the mail for reference).', 'But now UBS is not possible as their internship process is starting in March.', 'So, both the finance stations allotted to me got canceled.', 'Currently, my station allotment is in process.', 'By the time Rupeek Fintech got backed out, all the finance stations were filled.', 'I also feel that it is very difficult to get a finance station right now.']

# %%
print(keywords(texts1,words=4))
# Out:
# stations
# station
# got
# rupeek
# process

# %% [markdown]
# *In the above Keywords extraction algorithm, we treated keywords as nodes and performed page raning algorithm*

# %%
print(summarize(texts1,word_count=12))
# Out:
# By the time Rupeek Fintech got backed out, all the finance stations were filled.

# %%
print(keywords(texts1,words=4, lemmatize= False))
# Out:
# stations
# station
# got
# rupeek
# process

# %% [markdown]
# *If we don't use lemmatization both words from a root word are treated as diferent.*

# %%
print(keywords(texts1,words=4, lemmatize= True))
# Out:
# station
# got
# rupeek
# process

# %%
with open('Newspaper.txt', 'r', encoding= "utf8") as file:
texts2 = file.read().replace('\n','')
# Out:
#   File "<ipython-input-23-0959ad51540d>", line 2
#     texts2 = file.read().replace('\n','')
#     ^
# IndentationError: expected an indented block

# %%
source1= """this happened 5/6 years ago so my whole family every xmas day goes around to my aunties for celebrations. my cousin (of course) was there and he
asked if i wanted to play cops and robbers. i accepted of course. now, next to the side of my aunts house is a little area with a small fence, a covered
water tank and super duper sharp stones. my cousin (who was the cop) was gaining on me. i (tried) to jump over the fence, aaand i failed the jump
and went crashing onto the gravel, my leg hitting the sharpest bit and, then the next thing i knew it had a nasty gash."""

# %%
print(summarize(source1, ratio=0.5))
# Out:
# my cousin (of course) was there and he
# now, next to the side of my aunts house is a little area with a small fence, a covered
# my cousin (who was the cop) was gaining on me.
# i (tried) to jump over the fence, aaand i failed the jump

# %%
print(summarize(source1, ratio=0.8))
# Out:
# this happened 5/6 years ago so my whole family every xmas day goes around to my aunties for celebrations.
# my cousin (of course) was there and he
# asked if i wanted to play cops and robbers.
# i accepted of course.
# now, next to the side of my aunts house is a little area with a small fence, a covered
# my cousin (who was the cop) was gaining on me.
# i (tried) to jump over the fence, aaand i failed the jump

# %%
print(summarize(source1, ratio=0.3))
# Out:
# my cousin (of course) was there and he
# my cousin (who was the cop) was gaining on me.

# %%
source2= """throwaway here for obvious reasons.. today my friends and i decided to go off-roading in nowhereland. we packed up all our stuff, made the roughly
hour drive off to the mountains to make a fire, go fishing and just talk about life until we got too tired to stay any longer. we got everything packed
up and brought along one of my friends’ dog because she’s awesome and loves the outdoors. the dog was flipping out in the suv on the way to the
path because she knew was a kick-ass day she was about to have breaking out of her normally lame, domesticated dog life. my friends decided to
